# %%
import pandas as pd

# %%
import numpy as np

# %%
from sklearn.linear_model import LogisticRegression

# %%
df=pd.read_csv(r'C:\Users\Bala murukan\zaga-nec-hackathon-2\loanprediction.csv')

# %%
df.head()
# Out:
#    BAD  LOAN  MORTDUE     VALUE   REASON     JOB   YOJ  DEROG  DELINQ  \
# 0    1  1100  25860.0   39025.0  HomeImp   Other  10.5    0.0     0.0
# 1    1  1300  70053.0   68400.0  HomeImp   Other   7.0    0.0     2.0
# 2    1  1500  13500.0   16700.0  HomeImp   Other   4.0    0.0     0.0
# 3    1  1500      NaN       NaN      NaN     NaN   NaN    NaN     NaN
# 4    0  1700  97800.0  112000.0  HomeImp  Office   3.0    0.0     0.0
#
#         CLAGE  NINQ  CLNO  DEBTINC
# 0   94.366667   1.0   9.0      NaN
# 1  121.833333   0.0  14.0      NaN
# 2  149.466667   1.0  10.0      NaN
# 3         NaN   NaN   NaN      NaN
# 4   93.333333   0.0  14.0      NaN

# %%
df.tail()
# Out:
#       BAD   LOAN  MORTDUE    VALUE   REASON    JOB   YOJ  DEROG  DELINQ  \
# 5955    0  88900  57264.0  90185.0  DebtCon  Other  16.0    0.0     0.0
# 5956    0  89000  54576.0  92937.0  DebtCon  Other  16.0    0.0     0.0
# 5957    0  89200  54045.0  92924.0  DebtCon  Other  15.0    0.0     0.0
# 5958    0  89800  50370.0  91861.0  DebtCon  Other  14.0    0.0     0.0
# 5959    0  89900  48811.0  88934.0  DebtCon  Other  15.0    0.0     0.0
#
#            CLAGE  NINQ  CLNO    DEBTINC
# 5955  221.808718   0.0  16.0  36.112347
# 5956  208.692070   0.0  15.0  35.859971
# 5957  212.279697   0.0  15.0  35.556590
# 5958  213.892709   0.0  16.0  34.340882
# 5959  219.601002   0.0  16.0  34.571519

# %%
df.shape
# Out:
# (5960, 13)

# %%
df.columns
# Out:
# Index(['BAD', 'LOAN', 'MORTDUE', 'VALUE', 'REASON', 'JOB', 'YOJ', 'DEROG',
#        'DELINQ', 'CLAGE', 'NINQ', 'CLNO', 'DEBTINC'],
#       dtype='object')

# %%
df['REASON'].unique()
# Out:
# array(['HomeImp', nan, 'DebtCon'], dtype=object)

# %%
df['REASON']=df['REASON'].map({'HomeImp':0,'DebtCon':1,'NaN':2})

# %%
df['REASON'].unique()
# Out:
# array([ 0., nan,  1.])

# %%
median = df['REASON'].median()
df['REASON']=df['REASON'].fillna(median)

# %%
df['REASON'].unique()
# Out:
# array([0., 1.])

# %%
df['JOB'].unique()
# Out:
# array(['Other', nan, 'Office', 'Sales', 'Mgr', 'ProfExe', 'Self'],
#       dtype=object)

# %%
df['JOB']=df['JOB'].map({'Other':1,'Sales':2,'Mgr':3,'ProfExe':'4','Self':'5'})

# %%
df['JOB'].unique()
# Out:
# array([1, nan, 2, 3, '4', '5'], dtype=object)

# %%
median = df['JOB'].median()
df['JOB']=df['JOB'].fillna(median)

# %%
df['JOB'].unique()
# Out:
# array([1, 2, 3, '4', '5'], dtype=object)

# %%
df.columns
# Out:
# Index(['BAD', 'LOAN', 'MORTDUE', 'VALUE', 'REASON', 'JOB', 'YOJ', 'DEROG',
#        'DELINQ', 'CLAGE', 'NINQ', 'CLNO', 'DEBTINC'],
#       dtype='object')

# %%
df.head()
# Out:
#    BAD  LOAN  MORTDUE     VALUE  REASON  JOB   YOJ  DEROG  DELINQ       CLAGE  \
# 0    1  1100  25860.0   39025.0     0.0    1  10.5    0.0     0.0   94.366667
# 1    1  1300  70053.0   68400.0     0.0    1   7.0    0.0     2.0  121.833333
# 2    1  1500  13500.0   16700.0     0.0    1   4.0    0.0     0.0  149.466667
# 3    1  1500      NaN       NaN     1.0  1.0   NaN    NaN     NaN         NaN
# 4    0  1700  97800.0  112000.0     0.0  1.0   3.0    0.0     0.0   93.333333
#
#    NINQ  CLNO  DEBTINC
# 0   1.0   9.0      NaN
# 1   0.0  14.0      NaN
# 2   1.0  10.0      NaN
# 3   NaN   NaN      NaN
# 4   0.0  14.0      NaN

# %%
df.tail()
# Out:
#       BAD   LOAN  MORTDUE    VALUE  REASON JOB   YOJ  DEROG  DELINQ  \
# 5955    0  88900  57264.0  90185.0     1.0   1  16.0    0.0     0.0
# 5956    0  89000  54576.0  92937.0     1.0   1  16.0    0.0     0.0
# 5957    0  89200  54045.0  92924.0     1.0   1  15.0    0.0     0.0
# 5958    0  89800  50370.0  91861.0     1.0   1  14.0    0.0     0.0
# 5959    0  89900  48811.0  88934.0     1.0   1  15.0    0.0     0.0
#
#            CLAGE  NINQ  CLNO    DEBTINC
# 5955  221.808718   0.0  16.0  36.112347
# 5956  208.692070   0.0  15.0  35.859971
# 5957  212.279697   0.0  15.0  35.556590
# 5958  213.892709   0.0  16.0  34.340882
# 5959  219.601002   0.0  16.0  34.571519

# %%
df['CLAGE'].unique()
# Out:
# array([ 94.36666667, 121.83333333, 149.46666667, ..., 212.27969667,
#        213.89270901, 219.60100218], shape=(5315,))

# %%
df.drop_duplicates()
# Out:
#       BAD   LOAN  MORTDUE     VALUE  REASON  JOB   YOJ  DEROG  DELINQ  \
# 0       1   1100  25860.0   39025.0     0.0    1  10.5    0.0     0.0
# 1       1   1300  70053.0   68400.0     0.0    1   7.0    0.0     2.0
# 2       1   1500  13500.0   16700.0     0.0    1   4.0    0.0     0.0
# 3       1   1500      NaN       NaN     1.0  1.0   NaN    NaN     NaN
# 4       0   1700  97800.0  112000.0     0.0  1.0   3.0    0.0     0.0
# ...   ...    ...      ...       ...     ...  ...   ...    ...     ...
# 5955    0  88900  57264.0   90185.0     1.0    1  16.0    0.0     0.0
# 5956    0  89000  54576.0   92937.0     1.0    1  16.0    0.0     0.0
# 5957    0  89200  54045.0   92924.0     1.0    1  15.0    0.0     0.0
# 5958    0  89800  50370.0   91861.0     1.0    1  14.0    0.0     0.0
# 5959    0  89900  48811.0   88934.0     1.0    1  15.0    0.0     0.0
#
#            CLAGE  NINQ  CLNO    DEBTINC
# 0      94.366667   1.0   9.0        NaN
# 1     121.833333   0.0  14.0        NaN
# ...

# %%
df.shape
# Out:
# (5960, 13)

# %%
median = df['CLAGE'].median()
df['CLAGE']=df['CLAGE'].fillna(median)

# %%
df.head()
# Out:
#    BAD  LOAN  MORTDUE     VALUE  REASON  JOB   YOJ  DEROG  DELINQ       CLAGE  \
# 0    1  1100  25860.0   39025.0     0.0    1  10.5    0.0     0.0   94.366667
# 1    1  1300  70053.0   68400.0     0.0    1   7.0    0.0     2.0  121.833333
# 2    1  1500  13500.0   16700.0     0.0    1   4.0    0.0     0.0  149.466667
# 3    1  1500      NaN       NaN     1.0  1.0   NaN    NaN     NaN  173.466667
# 4    0  1700  97800.0  112000.0     0.0  1.0   3.0    0.0     0.0   93.333333
#
#    NINQ  CLNO  DEBTINC
# 0   1.0   9.0      NaN
# 1   0.0  14.0      NaN
# 2   1.0  10.0      NaN
# 3   NaN   NaN      NaN
# 4   0.0  14.0      NaN

# %%
median = df['CLNO'].median()
df['CLNO']=df['CLNO'].fillna(median)

# %%
median = df['DEBTINC'].median()
df['DEBTINC']=df['DEBTINC'].fillna(median)

# %%
median = df['NINQ'].median()
df['NINQ']=df['NINQ'].fillna(median)

# %%
median = df['DELINQ'].median()
df['DELINQ']=df['DELINQ'].fillna(median)

# %%
median = df['VALUE'].median()
df['VALUE']=df['VALUE'].fillna(median)

# %%
median = df['VALUE'].median()
df['VALUE']=df['VALUE'].fillna(median)

# %%
median = df['MORTDUE'].median()
df['MORTDUE']=df['MORTDUE'].fillna(median)

# %%
median = df['YOJ'].median()
df['YOJ']=df['YOJ'].fillna(median)

# %%
df.head()
# Out:
#    BAD  LOAN  MORTDUE     VALUE  REASON  JOB   YOJ  DEROG  DELINQ       CLAGE  \
# 0    1  1100  25860.0   39025.0     0.0    1  10.5    0.0     0.0   94.366667
# 1    1  1300  70053.0   68400.0     0.0    1   7.0    0.0     2.0  121.833333
# 2    1  1500  13500.0   16700.0     0.0    1   4.0    0.0     0.0  149.466667
# 3    1  1500  65019.0   89235.5     1.0  1.0   7.0    NaN     0.0  173.466667
# 4    0  1700  97800.0  112000.0     0.0  1.0   3.0    0.0     0.0   93.333333
#
#    NINQ  CLNO    DEBTINC
# 0   1.0   9.0  34.818262
# 1   0.0  14.0  34.818262
# 2   1.0  10.0  34.818262
# 3   1.0  20.0  34.818262
# 4   0.0  14.0  34.818262

# %%
median = df['DEROG'].median()
df['DEROG']=df['DEROG'].fillna(median)

# %%
df.head()
# Out:
#    BAD  LOAN  MORTDUE     VALUE  REASON  JOB   YOJ  DEROG  DELINQ       CLAGE  \
# 0    1  1100  25860.0   39025.0     0.0    1  10.5    0.0     0.0   94.366667
# 1    1  1300  70053.0   68400.0     0.0    1   7.0    0.0     2.0  121.833333
# 2    1  1500  13500.0   16700.0     0.0    1   4.0    0.0     0.0  149.466667
# 3    1  1500  65019.0   89235.5     1.0  1.0   7.0    0.0     0.0  173.466667
# 4    0  1700  97800.0  112000.0     0.0  1.0   3.0    0.0     0.0   93.333333
#
#    NINQ  CLNO    DEBTINC
# 0   1.0   9.0  34.818262
# 1   0.0  14.0  34.818262
# 2   1.0  10.0  34.818262
# 3   1.0  20.0  34.818262
# 4   0.0  14.0  34.818262

# %%
X=df[['LOAN','VALUE']]
y=df['REASON']
model=LogisticRegression()

# %%
model.fit(X,y)
print(model.predict(X))
# Out:
# [1. 1. 1. ... 1. 1. 1.]
